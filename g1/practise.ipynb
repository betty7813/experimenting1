# %%
n=int(input("Enter a number:"))
reverse=0
while(n>0):
    num=n%10
    reverse=reverse*10 + num
    n=n//10
print("Reverse:",reverse)
# Out:
# Enter a number: 324
# Reverse: 423

# %%
while True:
    user_input=input("Enter a number(enter space to stop):")
    if user_input==" ":
        break
print("Program has stopped")
# Out:
# Enter a number(enter space to stop): 2
# Enter a number(enter space to stop): 3
# Enter a number(enter space to stop): 4
# Enter a number(enter space to stop):
# Program has stopped

# %%
n=int(input("Enter the number of fruits:"))
list1=[]
for i in range(n):
    list1.insert(i,input("Enter the fruit:"))
print("Displaying the fruits:",list1)
# Out:
# Enter the number of fruits: 3
# Enter the fruit: kiwi
# Enter the fruit: mango
# Enter the fruit: apple
# Displaying the fruits: ['kiwi', 'mango', 'apple']

# %%
n=int(input("Enter the number of fruits:"))
list1=[]
for i in range(n):
    list1.insert(i,input("Enter the fruit:"))
print("Enter two more fruits:")
for i in range(2):
    list1.append(input("Enter:"))
print("Final list:",list1)
# Out:
# Enter the number of fruits: 2
# Enter the fruit: mago
# Enter the fruit: apple
# Enter two more fruits:
# Enter: bannaa
# Enter: maaa
# Final list: ['mago', 'apple', 'bannaa', 'maaa']

# %%
n=int(input("Enter the number of fruits:"))
list1=[]
for i in range(n):
    list1.insert(i,input("Enter the fruit:"))
for i in range(n):
    if 'i' in list1[i]:
        print(list1[i])
# Out:
# Enter the number of fruits: 1
# Enter the fruit: kiwi
# kiwi
